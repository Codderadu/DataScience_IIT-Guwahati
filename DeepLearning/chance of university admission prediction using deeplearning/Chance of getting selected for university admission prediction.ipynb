# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Admission_Predict.csv")

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.shape
# Out:
# (400, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.3 KB

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
df["University Rating"].value_counts()
# Out:
# University Rating
# 3    133
# 2    107
# 4     74
# 5     60
# 1     26
# Name: count, dtype: int64

# %% [markdown]
# most number of student admited in tier 3 and tier 4 college

# %%
df["CGPA"].value_counts()
# Out:
# CGPA
# 8.00    9
# 8.76    8
# 8.56    7
# 9.11    6
# 8.64    6
#        ..
# 9.32    1
# 9.48    1
# 9.56    1
# 7.28    1
# 7.96    1
# Name: count, Length: 168, dtype: int64

# %%
df["SOP"].value_counts()
# Out:
# SOP
# 4.0    70
# 3.5    70
# 3.0    64
# 4.5    53
# 2.5    47
# 5.0    37
# 2.0    33
# 1.5    20
# 1.0     6
# Name: count, dtype: int64

# %% [markdown]
# avg number of student got sop  of 4 which is good one

# %%
sns.distplot(x=df["SOP"])
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# most of the student having sop between 3 to 4

# %%
sns.distplot(x=df['LOR '])
# Out:
# <Axes: ylabel='Density'>

# %%
df["LOR "].value_counts()
# Out:
# LOR
# 3.0    85
# 4.0    77
# 3.5    73
# 4.5    45
# 2.5    39
# 2.0    38
# 5.0    35
# 1.5     7
# 1.0     1
# Name: count, dtype: int64

# %% [markdown]
# most number of student having lor is between 3 to 4

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
sns.jointplot(x = 'TOEFL Score', y = 'GRE Score', color = 'darkblue', data = df)

# %% [markdown]
# GREScore and TOEFL Score are the positively corelated

# %%
sns.jointplot(x = 'TOEFL Score', y = 'GRE Score', kind = 'kde', data = df, color = 'pink')

# %% [markdown]
# most number of student are score GRE score btn 315 to 325 and TOEFL score btn 105 to 110

# %%
sns.jointplot(x = 'CGPA', y = 'GRE Score', kind = 'hex', data = df)

# %% [markdown]
# Most of the students present in the dataset scored somewhere around 320 on the GRE and have a CGPA of 8.8. Additionally, there are a very few students who scored between 290 and 300 and then, got a 7.5 CGPA.

# %%
sns.jointplot(x = 'SOP', y = 'LOR ', kind = 'kde', color = 'g', data = df)

# %% [markdown]
# remove unwanted columns form data

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
X=df.drop(["Serial No.","Chance of Admit "],axis=1)
y=df["Chance of Admit "]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
minMax=MinMaxScaler()

# %%
X_train_scaled=minMax.fit_transform(X_train)
X_test_Scaled=minMax.transform(X_test)

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense
from keras import callbacks

# %%
model=keras.Sequential()

# %%
model.add(Dense(16,input_dim=7,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add()
model.add(Dense(4,activation='relu'))
model.add(Dense(1,activation="linear"))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓
# ┃ Layer (type)                       ┃ Output Shape                  ┃     Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩
# │ dense_19 (Dense)                   │ (None, 16)                    │         128 │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ dense_20 (Dense)                   │ (None, 8)                     │         136 │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ dense_21 (Dense)                   │ (None, 4)                     │          36 │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ dense_22 (Dense)                   │ (None, 1)                     │           5 │
# └────────────────────────────────────┴───────────────────────────────┴─────────────┘
# ...

# %%
model.compile(loss="mean_absolute_error",optimizer="adam")

# %%
history=model.fit(X_train_scaled,y_train,epochs=30,validation_split=0.2)
# Out:
# Epoch 1/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0481 - val_loss: 0.0386
# Epoch 2/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0505 - val_loss: 0.0357
# Epoch 3/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0478 - val_loss: 0.0403
# Epoch 4/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0489 - val_loss: 0.0355
# Epoch 5/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0454 - val_loss: 0.0389
# Epoch 6/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0487 - val_loss: 0.0395
# Epoch 7/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0471 - val_loss: 0.0361
# Epoch 8/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0457 - val_loss: 0.0365
# Epoch 9/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0520 - val_loss: 0.0371
# Epoch 10/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0448 - val_loss: 0.0384
# Epoch 11/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0424 - val_loss: 0.0355
# Epoch 12/30
# ...

# %%
y_pred=model.predict(X_test_Scaled)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_pred,y_test)
# Out:
# 0.6104029150238649

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
